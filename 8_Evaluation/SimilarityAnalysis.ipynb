# %% [markdown]
# ## Get data from PubMed

# %% [markdown]
# # DrugBank

# %%
import voyageai
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Use Voyage AI API KEY
api_key = os.getenv("VOYAGE_AI_API_KEY")

vo = voyageai.Client(api_key=api_key)
# This will automatically use the environment variable VOYAGE_API_KEY.
# Alternatively, you can use vo = voyageai.Client(api_key="<your secret key>")

result = vo.embed(["hello world"], model="voyage-large-2")

# %%
# Set a distinct number of drug categories
distinct_drug_categories = [
    'Analgesics',
    'Antibiotics',
    'Antifungal Agents',
    'Antiviral Agents',
    'Antipyretics',
    'Antiseptics',
    'Mood Stabilizers',
    'Anti-Inflammatory Agents',
    'Anticoagulants',
    'Antihistamines',
    'Diuretics',
    'Laxatives',
    'Bronchodilators',
    'Anticonvulsants',
    'Antidepressants'
]

# %%
def embed_vector(list_of_text):
    list_of_text: list
    if type(list_of_text) == list:
        result = vo.embed(list_of_text, model="voyage-large-2")
    else:
        print("The input must be a list")
        return TypeError
    return result.embeddings

def best_drug_category(categories, standard_list):
    vecs = embed_vector([categories]+standard_list)
    vec_array = np.array(vecs)

    # Calculate cosine similarity
    similarity_matrix = cosine_similarity(vec_array)

    first_line_similarities = similarity_matrix[0, 1:]

    # Find the index of the highest similarity
    best_fit_index = np.argmax(first_line_similarities)

    # Get the corresponding category
    best_fit_category = distinct_drug_categories[best_fit_index]

    return best_fit_category

def plot_variance_distribution(data):
    plt.figure(figsize=(8, 6))
    sns.histplot(data, bins=20, kde=True)
    plt.title('Distribution of Variance Values (without self-similarity)')
    plt.xlabel('Variance')
    plt.ylabel('Frequency')
    plt.show()
    return True

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Base URL for DrugBank
base_url = "https://go.drugbank.com/drugs/"

# Range of DrugBank IDs to scrape
start_id = 1000
end_id = 2000  # Example range, adjust as needed

# Initialize a list to store drug data
drugs_data = []

for i in range(start_id, end_id + 1):
    drug_id = f"DB{i:05d}"
    url = f"{base_url}{drug_id}"
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract the drug ID
        drug_id_meta = soup.find('meta', attrs={'name': 'dc.identifier'})
        drug_id_value = drug_id_meta['content'] if drug_id_meta else 'N/A'
        
        # Extract the drug name
        drug_name_meta = soup.find('meta', attrs={'name': 'dc.title'})
        drug_name = drug_name_meta['content'] if drug_name_meta else 'N/A'
        
        # Extract the drug description
        description_meta = soup.find('meta', attrs={'name': 'description'})
        description = description_meta['content'] if description_meta else 'N/A'
        
        # Extract additional fields by looking for dt/dd pairs
        def get_text_for_label(label):
            tag = soup.find('dt', text=label)
            if tag:
                next_tag = tag.find_next_sibling('dd')
                if next_tag:
                    return next_tag.text.strip()
            return 'N/A'

        # Data to collect
        mechanism_of_action = get_text_for_label('Mechanism of action')
        indication = get_text_for_label('Indication')
        pharmacodynamics = get_text_for_label('Pharmacodynamics')
        absorption = get_text_for_label('Absorption')
        volume_of_distribution = get_text_for_label('Volume of distribution')
        protein_binding = get_text_for_label('Protein binding')
        metabolism = get_text_for_label('Metabolism')
        drug_categories = get_text_for_label('Drug Categories')

        # Append the data to the list
        drugs_data.append({
            'DrugBank ID': drug_id_value,
            'Name': drug_name,
            'Description': description,
            'Mechanism of Action': mechanism_of_action,
            'Indication': indication,
            'Pharmacodynamics': pharmacodynamics,
            'Absorption': absorption,
            'Volume of Distribution': volume_of_distribution,
            'Protein Binding': protein_binding,
            'Metabolism': metabolism,
            'Drug Categories': drug_categories,
            # Add more fields as necessary
        })
        print(f"Gathered data for {drug_id}")
        # Just so not to overwhelm the server 
        time.sleep(0.01)
    else:
        print(f"Failed to retrieve data for {drug_id}")

# Convert the list to a pandas DataFrame
df = pd.DataFrame(drugs_data)
# Out:
# /var/folders/fq/jhg4d1x54s7djyrxjpq4h4b80000gn/T/ipykernel_12116/1796460271.py:38: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tag = soup.find('dt', text=label)
# Gathered data for DB01000
# Gathered data for DB01001
# Gathered data for DB01002
# Gathered data for DB01003
# Gathered data for DB01004
# Gathered data for DB01005
# Gathered data for DB01006
# Gathered data for DB01007
# Gathered data for DB01008
# Gathered data for DB01009
# Gathered data for DB01010
# Gathered data for DB01011
# Gathered data for DB01012
# Gathered data for DB01013
# Gathered data for DB01014
# Gathered data for DB01015
# Gathered data for DB01016
# Gathered data for DB01017
# Gathered data for DB01018
# Gathered data for DB01019
# Gathered data for DB01020
# Gathered data for DB01021
# Gathered data for DB01022
# Gathered data for DB01023
# Gathered data for DB01024
# Gathered data for DB01025
# Gathered data for DB01026
# Failed to retrieve data for DB01027
# Gathered data for DB01028
# Gathered data for DB01029
# Gathered data for DB01030
# Gathered data for DB01031
# Gathered data for DB01032
# Gathered data for DB01033
# Gathered data for DB01034
# Gathered data for DB01035
# Gathered data for DB01036
# Gathered data for DB01037
# Gathered data for DB01038
# Gathered data for DB01039
# Gathered data for DB01040
# Gathered data for DB01041
# Gathered data for DB01042
# Gathered data for DB01043
# Gathered data for DB01044
# Gathered data for DB01045
# Gathered data for DB01046
# Gathered data for DB01047
# Gathered data for DB01048
# Gathered data for DB01049
# Gathered data for DB01050
# Gathered data for DB01051
# Failed to retrieve data for DB01052
# Gathered data for DB01053
# Gathered data for DB01054
# Gathered data for DB01055
# Gathered data for DB01056
# Gathered data for DB01057
# Gathered data for DB01058
# Gathered data for DB01059
# Gathered data for DB01060
# Gathered data for DB01061
# Gathered data for DB01062
# Gathered data for DB01063
# Gathered data for DB01064
# Gathered data for DB01065
# Gathered data for DB01066
# Gathered data for DB01067
# Gathered data for DB01068
# Gathered data for DB01069
# Gathered data for DB01070
# Gathered data for DB01071
# Gathered data for DB01072
# Gathered data for DB01073
# Gathered data for DB01074
# Gathered data for DB01075
# Gathered data for DB01076
# Gathered data for DB01077
# Gathered data for DB01078
# Gathered data for DB01079
# Gathered data for DB01080
# Gathered data for DB01081
# Gathered data for DB01082
# Gathered data for DB01083
# Gathered data for DB01084
# Gathered data for DB01085
# Gathered data for DB01086
# Gathered data for DB01087
# Gathered data for DB01088
# Gathered data for DB01089
# Gathered data for DB01090
# Gathered data for DB01091
# Gathered data for DB01092
# Gathered data for DB01093
# Gathered data for DB01094
# Gathered data for DB01095
# Gathered data for DB01096
# Gathered data for DB01097
# Gathered data for DB01098
# Gathered data for DB01099
# Gathered data for DB01100
# Gathered data for DB01101
# Gathered data for DB01102
# Gathered data for DB01103
# Gathered data for DB01104
# Gathered data for DB01105
# Gathered data for DB01106
# Gathered data for DB01107
# Gathered data for DB01108
# Gathered data for DB01109
# Gathered data for DB01110
# Gathered data for DB01111
# Gathered data for DB01112
# Gathered data for DB01113
# Gathered data for DB01114
# Gathered data for DB01115
# Gathered data for DB01116
# Gathered data for DB01117
# Gathered data for DB01118
# Gathered data for DB01119
# Gathered data for DB01120
# Gathered data for DB01121
# Gathered data for DB01122
# Gathered data for DB01123
# Gathered data for DB01124
# Gathered data for DB01125
# Gathered data for DB01126
# Gathered data for DB01127
# Gathered data for DB01128
# Gathered data for DB01129
# Gathered data for DB01130
# Gathered data for DB01131
# Gathered data for DB01132
# Gathered data for DB01133
# Gathered data for DB01134
# Gathered data for DB01135
# Gathered data for DB01136
# Gathered data for DB01137
# Gathered data for DB01138
# Gathered data for DB01139
# Gathered data for DB01140
# Gathered data for DB01141
# Gathered data for DB01142
# Gathered data for DB01143
# Gathered data for DB01144
# Gathered data for DB01145
# Gathered data for DB01146
# Gathered data for DB01147
# Gathered data for DB01148
# Gathered data for DB01149
# Gathered data for DB01150
# Gathered data for DB01151
# Gathered data for DB01152
# Gathered data for DB01153
# Gathered data for DB01154
# Gathered data for DB01155
# Gathered data for DB01156
# Gathered data for DB01157
# Gathered data for DB01158
# Gathered data for DB01159
# Gathered data for DB01160
# Gathered data for DB01161
# Gathered data for DB01162
# Gathered data for DB01163
# Gathered data for DB01164
# Gathered data for DB01165
# Gathered data for DB01166
# Gathered data for DB01167
# Gathered data for DB01168
# Gathered data for DB01169
# Gathered data for DB01170
# Gathered data for DB01171
# Gathered data for DB01172
# Gathered data for DB01173
# Gathered data for DB01174
# Gathered data for DB01175
# Gathered data for DB01176
# Gathered data for DB01177
# Gathered data for DB01178
# Gathered data for DB01179
# Gathered data for DB01180
# Gathered data for DB01181
# Gathered data for DB01182
# Gathered data for DB01183
# Gathered data for DB01184
# Gathered data for DB01185
# Gathered data for DB01186
# Gathered data for DB01187
# Gathered data for DB01188
# Gathered data for DB01189
# Gathered data for DB01190
# Gathered data for DB01191
# Gathered data for DB01192
# Gathered data for DB01193
# Gathered data for DB01194
# Gathered data for DB01195
# Gathered data for DB01196
# Gathered data for DB01197
# Gathered data for DB01198
# Gathered data for DB01199
# Gathered data for DB01200
# Gathered data for DB01201
# Gathered data for DB01202
# Gathered data for DB01203
# Gathered data for DB01204
# Gathered data for DB01205
# Gathered data for DB01206
# Gathered data for DB01207
# Gathered data for DB01208
# Gathered data for DB01209
# Gathered data for DB01210
# Gathered data for DB01211
# Gathered data for DB01212
# Gathered data for DB01213
# Gathered data for DB01214
# Gathered data for DB01215
# Gathered data for DB01216
# Gathered data for DB01217
# Gathered data for DB01218
# Gathered data for DB01219
# Gathered data for DB01220
# Gathered data for DB01221
# Gathered data for DB01222
# Gathered data for DB01223
# Gathered data for DB01224
# Gathered data for DB01225
# Gathered data for DB01226
# Gathered data for DB01227
# Gathered data for DB01228
# Gathered data for DB01229
# Gathered data for DB01230
# Gathered data for DB01231
# Gathered data for DB01232
# Gathered data for DB01233
# Gathered data for DB01234
# Gathered data for DB01235
# Gathered data for DB01236
# Gathered data for DB01237
# Gathered data for DB01238
# Gathered data for DB01239
# Gathered data for DB01240
# Gathered data for DB01241
# Gathered data for DB01242
# Gathered data for DB01243
# Gathered data for DB01244
# Gathered data for DB01245
# Gathered data for DB01246
# Gathered data for DB01247
# Gathered data for DB01248
# Gathered data for DB01249
# Gathered data for DB01250
# Gathered data for DB01251
# Gathered data for DB01252
# Gathered data for DB01253
# Gathered data for DB01254
# Gathered data for DB01255
# Gathered data for DB01256
# Gathered data for DB01257
# Gathered data for DB01258
# Gathered data for DB01259
# Gathered data for DB01260
# Gathered data for DB01261
# Gathered data for DB01262
# Gathered data for DB01263
# Gathered data for DB01264
# Gathered data for DB01265
# Gathered data for DB01266
# Gathered data for DB01267
# Gathered data for DB01268
# Gathered data for DB01269
# Gathered data for DB01270
# Gathered data for DB01271
# Gathered data for DB01272
# Gathered data for DB01273
# Gathered data for DB01274
# Gathered data for DB01275
# Gathered data for DB01276
# Gathered data for DB01277
# Gathered data for DB01278
# Gathered data for DB01279
# Gathered data for DB01280
# Gathered data for DB01281
# Gathered data for DB01282
# Gathered data for DB01283
# Gathered data for DB01284
# Gathered data for DB01285
# Failed to retrieve data for DB01286
# Gathered data for DB01287
# Gathered data for DB01288
# Gathered data for DB01289
# Failed to retrieve data for DB01290
# Gathered data for DB01291
# Failed to retrieve data for DB01292
# Failed to retrieve data for DB01293
# Gathered data for DB01294
# Gathered data for DB01295
# Gathered data for DB01296
# Gathered data for DB01297
# Gathered data for DB01298
# Gathered data for DB01299
# Failed to retrieve data for DB01300
# Gathered data for DB01301
# Failed to retrieve data for DB01302
# Gathered data for DB01303
# Failed to retrieve data for DB01304
# Failed to retrieve data for DB01305
# Gathered data for DB01306
# Gathered data for DB01307
# Gathered data for DB01308
# Gathered data for DB01309
# Gathered data for DB01310
# Failed to retrieve data for DB01311
# Failed to retrieve data for DB01312
# Failed to retrieve data for DB01313
# Failed to retrieve data for DB01314
# Failed to retrieve data for DB01315
# Failed to retrieve data for DB01316
# Failed to retrieve data for DB01317
# Failed to retrieve data for DB01318
# Gathered data for DB01319
# Gathered data for DB01320
# Gathered data for DB01321
# Gathered data for DB01322
# Gathered data for DB01323
# Gathered data for DB01324
# Gathered data for DB01325
# Gathered data for DB01326
# Gathered data for DB01327
# Gathered data for DB01328
# Gathered data for DB01329
# Gathered data for DB01330
# Gathered data for DB01331
# Gathered data for DB01332
# Gathered data for DB01333
# Gathered data for DB01334
# Failed to retrieve data for DB01335
# Gathered data for DB01336
# Gathered data for DB01337
# Gathered data for DB01338
# Gathered data for DB01339
# Gathered data for DB01340
# Gathered data for DB01341
# Gathered data for DB01342
# Failed to retrieve data for DB01343
# Gathered data for DB01344
# Gathered data for DB01345
# Gathered data for DB01346
# Gathered data for DB01347
# Gathered data for DB01348
# Gathered data for DB01349
# Failed to retrieve data for DB01350
# Gathered data for DB01351
# Gathered data for DB01352
# Gathered data for DB01353
# Gathered data for DB01354
# Gathered data for DB01355
# Gathered data for DB01356
# Gathered data for DB01357
# Failed to retrieve data for DB01358
# Gathered data for DB01359
# Failed to retrieve data for DB01360
# Gathered data for DB01361
# Gathered data for DB01362
# Gathered data for DB01363
# Gathered data for DB01364
# Gathered data for DB01365
# Gathered data for DB01366
# Gathered data for DB01367
# Failed to retrieve data for DB01368
# Gathered data for DB01369
# Gathered data for DB01370
# Failed to retrieve data for DB01371
# Failed to retrieve data for DB01372
# Gathered data for DB01373
# Failed to retrieve data for DB01374
# Gathered data for DB01375
# Failed to retrieve data for DB01376
# Gathered data for DB01377
# Gathered data for DB01378
# Failed to retrieve data for DB01379
# Gathered data for DB01380
# Gathered data for DB01381
# Gathered data for DB01382
# Gathered data for DB01383
# Gathered data for DB01384
# Failed to retrieve data for DB01385
# Failed to retrieve data for DB01386
# Failed to retrieve data for DB01387
# Gathered data for DB01388
# Failed to retrieve data for DB01389
# Gathered data for DB01390
# Failed to retrieve data for DB01391
# Gathered data for DB01392
# Gathered data for DB01393
# Gathered data for DB01394
# Gathered data for DB01395
# Gathered data for DB01396
# Gathered data for DB01397
# Gathered data for DB01398
# Gathered data for DB01399
# Gathered data for DB01400
# Gathered data for DB01401
# Gathered data for DB01402
# Gathered data for DB01403
# Gathered data for DB01404
# Gathered data for DB01405
# Gathered data for DB01406
# Gathered data for DB01407
# Gathered data for DB01408
# Gathered data for DB01409
# Gathered data for DB01410
# Gathered data for DB01411
# Gathered data for DB01412
# Gathered data for DB01413
# Gathered data for DB01414
# Gathered data for DB01415
# Gathered data for DB01416
# Failed to retrieve data for DB01417
# Gathered data for DB01418
# Gathered data for DB01419
# Gathered data for DB01420
# Gathered data for DB01421
# Gathered data for DB01422
# Gathered data for DB01423
# Gathered data for DB01424
# Gathered data for DB01425
# Gathered data for DB01426
# Gathered data for DB01427
# Gathered data for DB01428
# Gathered data for DB01429
# Gathered data for DB01430
# Gathered data for DB01431
# Gathered data for DB01432
# Gathered data for DB01433
# Gathered data for DB01434
# Gathered data for DB01435
# Gathered data for DB01436
# Gathered data for DB01437
# Gathered data for DB01438
# Gathered data for DB01439
# Gathered data for DB01440
# Gathered data for DB01441
# Gathered data for DB01442
# Gathered data for DB01443
# Gathered data for DB01444
# Gathered data for DB01445
# Gathered data for DB01446
# Gathered data for DB01447
# Gathered data for DB01448
# Failed to retrieve data for DB01449
# Gathered data for DB01450
# Gathered data for DB01451
# Gathered data for DB01452
# Gathered data for DB01453
# Gathered data for DB01454
# Gathered data for DB01455
# Gathered data for DB01456
# Failed to retrieve data for DB01457
# Gathered data for DB01458
# Gathered data for DB01459
# Gathered data for DB01460
# Gathered data for DB01461
# Gathered data for DB01462
# Gathered data for DB01463
# Gathered data for DB01464
# Gathered data for DB01465
# Gathered data for DB01466
# Gathered data for DB01467
# Gathered data for DB01468
# Gathered data for DB01469
# Gathered data for DB01470
# Gathered data for DB01471
# Gathered data for DB01472
# Gathered data for DB01473
# Gathered data for DB01474
# Gathered data for DB01475
# Gathered data for DB01476
# Gathered data for DB01477
# Gathered data for DB01478
# Gathered data for DB01479
# Gathered data for DB01480
# Gathered data for DB01481
# Gathered data for DB01482
# Gathered data for DB01483
# Gathered data for DB01484
# Gathered data for DB01485
# Gathered data for DB01486
# Gathered data for DB01487
# Gathered data for DB01488
# Gathered data for DB01489
# Gathered data for DB01490
# Gathered data for DB01491
# Failed to retrieve data for DB01492
# Gathered data for DB01493
# Gathered data for DB01494
# Gathered data for DB01495
# Gathered data for DB01496
# Gathered data for DB01497
# Gathered data for DB01498
# Gathered data for DB01499
# Gathered data for DB01500
# Gathered data for DB01501
# Gathered data for DB01502
# Gathered data for DB01503
# Failed to retrieve data for DB01504
# Gathered data for DB01505
# Gathered data for DB01506
# Gathered data for DB01507
# Failed to retrieve data for DB01508
# Gathered data for DB01509
# Gathered data for DB01510
# Gathered data for DB01511
# Gathered data for DB01512
# Gathered data for DB01513
# Gathered data for DB01514
# Gathered data for DB01515
# Gathered data for DB01516
# Failed to retrieve data for DB01517
# Gathered data for DB01518
# Failed to retrieve data for DB01519
# Gathered data for DB01520
# Gathered data for DB01521
# Gathered data for DB01522
# Gathered data for DB01523
# Gathered data for DB01524
# Gathered data for DB01525
# Gathered data for DB01526
# Gathered data for DB01527
# Gathered data for DB01528
# Gathered data for DB01529
# Gathered data for DB01530
# Gathered data for DB01531
# Gathered data for DB01532
# Gathered data for DB01533
# Gathered data for DB01534
# Gathered data for DB01535
# Gathered data for DB01536
# Gathered data for DB01537
# Gathered data for DB01538
# Gathered data for DB01539
# Gathered data for DB01540
# Gathered data for DB01541
# Gathered data for DB01542
# Gathered data for DB01543
# Gathered data for DB01544
# Gathered data for DB01545
# Gathered data for DB01546
# Gathered data for DB01547
# Gathered data for DB01548
# Gathered data for DB01549
# Gathered data for DB01550
# Gathered data for DB01551
# Gathered data for DB01552
# Gathered data for DB01553
# Gathered data for DB01554
# Gathered data for DB01555
# Gathered data for DB01556
# Gathered data for DB01557
# Gathered data for DB01558
# Gathered data for DB01559
# Gathered data for DB01560
# Gathered data for DB01561
# Gathered data for DB01562
# Gathered data for DB01563
# Gathered data for DB01564
# Gathered data for DB01565
# Gathered data for DB01566
# Gathered data for DB01567
# Gathered data for DB01568
# Gathered data for DB01569
# Gathered data for DB01570
# Gathered data for DB01571
# Gathered data for DB01572
# Gathered data for DB01573
# Gathered data for DB01574
# Gathered data for DB01575
# Gathered data for DB01576
# Gathered data for DB01577
# Gathered data for DB01578
# Gathered data for DB01579
# Gathered data for DB01580
# Gathered data for DB01581
# Gathered data for DB01582
# Gathered data for DB01583
# Gathered data for DB01584
# Failed to retrieve data for DB01585
# Gathered data for DB01586
# Gathered data for DB01587
# Gathered data for DB01588
# Gathered data for DB01589
# Gathered data for DB01590
# Gathered data for DB01591
# Gathered data for DB01592
# Gathered data for DB01593
# Gathered data for DB01594
# Gathered data for DB01595
# Failed to retrieve data for DB01596
# Gathered data for DB01597
# Gathered data for DB01598
# Gathered data for DB01599
# Gathered data for DB01600
# Gathered data for DB01601
# Gathered data for DB01602
# Gathered data for DB01603
# Gathered data for DB01604
# Gathered data for DB01605
# Gathered data for DB01606
# Gathered data for DB01607
# Gathered data for DB01608
# Gathered data for DB01609
# Gathered data for DB01610
# Gathered data for DB01611
# Gathered data for DB01612
# Gathered data for DB01613
# Gathered data for DB01614
# Gathered data for DB01615
# Gathered data for DB01616
# Failed to retrieve data for DB01617
# Gathered data for DB01618
# Gathered data for DB01619
# Gathered data for DB01620
# Gathered data for DB01621
# Gathered data for DB01622
# Gathered data for DB01623
# Gathered data for DB01624
# Gathered data for DB01625
# Gathered data for DB01626
# Gathered data for DB01627
# Gathered data for DB01628
# Gathered data for DB01629
# Gathered data for DB01630
# Gathered data for DB01631
# Gathered data for DB01632
# Gathered data for DB01633
# Gathered data for DB01634
# Gathered data for DB01635
# Gathered data for DB01636
# Gathered data for DB01637
# Gathered data for DB01638
# Gathered data for DB01639
# Gathered data for DB01640
# Gathered data for DB01641
# Gathered data for DB01642
# Gathered data for DB01643
# Gathered data for DB01644
# Gathered data for DB01645
# Gathered data for DB01646
# Gathered data for DB01647
# Gathered data for DB01648
# Gathered data for DB01649
# Gathered data for DB01650
# Gathered data for DB01651
# Gathered data for DB01652
# Gathered data for DB01653
# Gathered data for DB01654
# Gathered data for DB01655
# Gathered data for DB01656
# Gathered data for DB01657
# Gathered data for DB01658
# Gathered data for DB01659
# Gathered data for DB01660
# Gathered data for DB01661
# Gathered data for DB01662
# Gathered data for DB01663
# Gathered data for DB01664
# Gathered data for DB01665
# Gathered data for DB01666
# Gathered data for DB01667
# Gathered data for DB01668
# Gathered data for DB01669
# Gathered data for DB01670
# Gathered data for DB01671
# Gathered data for DB01672
# Gathered data for DB01673
# Gathered data for DB01674
# Gathered data for DB01675
# Gathered data for DB01676
# Gathered data for DB01677
# Gathered data for DB01678
# Gathered data for DB01679
# Failed to retrieve data for DB01680
# Gathered data for DB01681
# Gathered data for DB01682
# Gathered data for DB01683
# Gathered data for DB01684
# Gathered data for DB01685
# Gathered data for DB01686
# Gathered data for DB01687
# Gathered data for DB01688
# Gathered data for DB01689
# Gathered data for DB01690
# Gathered data for DB01691
# Gathered data for DB01692
# Gathered data for DB01693
# Gathered data for DB01694
# Gathered data for DB01695
# Gathered data for DB01696
# Gathered data for DB01697
# Gathered data for DB01698
# Gathered data for DB01699
# Gathered data for DB01700
# Gathered data for DB01701
# Gathered data for DB01702
# Gathered data for DB01703
# Gathered data for DB01704
# Gathered data for DB01705
# Gathered data for DB01706
# Gathered data for DB01707
# Gathered data for DB01708
# Gathered data for DB01709
# Gathered data for DB01710
# Gathered data for DB01711
# Gathered data for DB01712
# Gathered data for DB01713
# Gathered data for DB01714
# Gathered data for DB01715
# Gathered data for DB01716
# Gathered data for DB01717
# Gathered data for DB01718
# Gathered data for DB01719
# Gathered data for DB01720
# Gathered data for DB01721
# Failed to retrieve data for DB01722
# Gathered data for DB01723
# Gathered data for DB01724
# Gathered data for DB01725
# Gathered data for DB01726
# Gathered data for DB01727
# Gathered data for DB01728
# Gathered data for DB01729
# Gathered data for DB01730
# Gathered data for DB01731
# Gathered data for DB01732
# Gathered data for DB01733
# Gathered data for DB01734
# Gathered data for DB01735
# Gathered data for DB01736
# Gathered data for DB01737
# Gathered data for DB01738
# Gathered data for DB01739
# Gathered data for DB01740
# Gathered data for DB01741
# Gathered data for DB01742
# Gathered data for DB01743
# Gathered data for DB01744
# Gathered data for DB01745
# Gathered data for DB01746
# Gathered data for DB01747
# Gathered data for DB01748
# Gathered data for DB01749
# Gathered data for DB01750
# Gathered data for DB01751
# Gathered data for DB01752
# Gathered data for DB01753
# Gathered data for DB01754
# Gathered data for DB01755
# Gathered data for DB01756
# Failed to retrieve data for DB01757
# Gathered data for DB01758
# Gathered data for DB01759
# Gathered data for DB01760
# Gathered data for DB01761
# Gathered data for DB01762
# Gathered data for DB01763
# Gathered data for DB01764
# Gathered data for DB01765
# Gathered data for DB01766
# Gathered data for DB01767
# Gathered data for DB01768
# Gathered data for DB01769
# Failed to retrieve data for DB01770
# Gathered data for DB01771
# Gathered data for DB01772
# Gathered data for DB01773
# Gathered data for DB01774
# Gathered data for DB01775
# Gathered data for DB01776
# Gathered data for DB01777
# Gathered data for DB01778
# Gathered data for DB01779
# Gathered data for DB01780
# Failed to retrieve data for DB01781
# Gathered data for DB01782
# Gathered data for DB01783
# Gathered data for DB01784
# Gathered data for DB01785
# Gathered data for DB01786
# Failed to retrieve data for DB01787
# Gathered data for DB01788
# Gathered data for DB01789
# Gathered data for DB01790
# Gathered data for DB01791
# Gathered data for DB01792
# Gathered data for DB01793
# Gathered data for DB01794
# Gathered data for DB01795
# Gathered data for DB01796
# Gathered data for DB01797
# Gathered data for DB01798
# Gathered data for DB01799
# Gathered data for DB01800
# Failed to retrieve data for DB01801
# Gathered data for DB01802
# Gathered data for DB01803
# Gathered data for DB01804
# Gathered data for DB01805
# Gathered data for DB01806
# Gathered data for DB01807
# Gathered data for DB01808
# Gathered data for DB01809
# Gathered data for DB01810
# Gathered data for DB01811
# Gathered data for DB01812
# Gathered data for DB01813
# Gathered data for DB01814
# Gathered data for DB01815
# Gathered data for DB01816
# Gathered data for DB01817
# Gathered data for DB01818
# Gathered data for DB01819
# Gathered data for DB01820
# Gathered data for DB01821
# Gathered data for DB01822
# Gathered data for DB01823
# Gathered data for DB01824
# Gathered data for DB01825
# Gathered data for DB01826
# Gathered data for DB01827
# Gathered data for DB01828
# Gathered data for DB01829
# Gathered data for DB01830
# Gathered data for DB01831
# Gathered data for DB01832
# Gathered data for DB01833
# Gathered data for DB01834
# Gathered data for DB01835
# Gathered data for DB01836
# Gathered data for DB01837
# Gathered data for DB01838
# Gathered data for DB01839
# Gathered data for DB01840
# Gathered data for DB01841
# Gathered data for DB01842
# Gathered data for DB01843
# Gathered data for DB01844
# Failed to retrieve data for DB01845
# Gathered data for DB01846
# Gathered data for DB01847
# Gathered data for DB01848
# Gathered data for DB01849
# Gathered data for DB01850
# Gathered data for DB01851
# Gathered data for DB01852
# Gathered data for DB01853
# Gathered data for DB01854
# Gathered data for DB01855
# Gathered data for DB01856
# Gathered data for DB01857
# Gathered data for DB01858
# Gathered data for DB01859
# Gathered data for DB01860
# Gathered data for DB01861
# Gathered data for DB01862
# Gathered data for DB01863
# Gathered data for DB01864
# Gathered data for DB01865
# Gathered data for DB01866
# Failed to retrieve data for DB01867
# Gathered data for DB01868
# Gathered data for DB01869
# Gathered data for DB01870
# Gathered data for DB01871
# Gathered data for DB01872
# Gathered data for DB01873
# Gathered data for DB01874
# Gathered data for DB01875
# Gathered data for DB01876
# Gathered data for DB01877
# Gathered data for DB01878
# Gathered data for DB01879
# Gathered data for DB01880
# Gathered data for DB01881
# Gathered data for DB01882
# Gathered data for DB01883
# Gathered data for DB01884
# Gathered data for DB01885
# Failed to retrieve data for DB01886
# Gathered data for DB01887
# Gathered data for DB01888
# Gathered data for DB01889
# Gathered data for DB01890
# Gathered data for DB01891
# Gathered data for DB01892
# Gathered data for DB01893
# Gathered data for DB01894
# Gathered data for DB01895
# Gathered data for DB01896
# Gathered data for DB01897
# Gathered data for DB01898
# Gathered data for DB01899
# Gathered data for DB01900
# Gathered data for DB01901
# Gathered data for DB01902
# Gathered data for DB01903
# Gathered data for DB01904
# Gathered data for DB01905
# Gathered data for DB01906
# Gathered data for DB01907
# Gathered data for DB01908
# Gathered data for DB01909
# Gathered data for DB01910
# Gathered data for DB01911
# Gathered data for DB01912
# Failed to retrieve data for DB01913
# Gathered data for DB01914
# Gathered data for DB01915
# Failed to retrieve data for DB01916
# Gathered data for DB01917
# Gathered data for DB01918
# Gathered data for DB01919
# Gathered data for DB01920
# Gathered data for DB01921
# Gathered data for DB01922
# Gathered data for DB01923
# Gathered data for DB01924
# Gathered data for DB01925
# Gathered data for DB01926
# Gathered data for DB01927
# Gathered data for DB01928
# Gathered data for DB01929
# Gathered data for DB01930
# Gathered data for DB01931
# Gathered data for DB01932
# Gathered data for DB01933
# Gathered data for DB01934
# Gathered data for DB01935
# Gathered data for DB01936
# Gathered data for DB01937
# Gathered data for DB01938
# Gathered data for DB01939
# Gathered data for DB01940
# Gathered data for DB01941
# Gathered data for DB01942
# Failed to retrieve data for DB01943
# Gathered data for DB01944
# Gathered data for DB01945
# Gathered data for DB01946
# Gathered data for DB01947
# Gathered data for DB01948
# Gathered data for DB01949
# Gathered data for DB01950
# Gathered data for DB01951
# Gathered data for DB01952
# Gathered data for DB01953
# Gathered data for DB01954
# Gathered data for DB01955
# Gathered data for DB01956
# Gathered data for DB01957
# Gathered data for DB01958
# Gathered data for DB01959
# Gathered data for DB01960
# Gathered data for DB01961
# Gathered data for DB01962
# Gathered data for DB01963
# Gathered data for DB01964
# Gathered data for DB01965
# Gathered data for DB01966
# Gathered data for DB01967
# Gathered data for DB01968
# Gathered data for DB01969
# Gathered data for DB01970
# Gathered data for DB01971
# Gathered data for DB01972
# Gathered data for DB01973
# Gathered data for DB01974
# Gathered data for DB01975
# Gathered data for DB01976
# Gathered data for DB01977
# Gathered data for DB01978
# Gathered data for DB01979
# Gathered data for DB01980
# Gathered data for DB01981
# Gathered data for DB01982
# Gathered data for DB01983
# Gathered data for DB01984
# Gathered data for DB01985
# Gathered data for DB01986
# Gathered data for DB01987
# Gathered data for DB01988
# Gathered data for DB01989
# Gathered data for DB01990
# Gathered data for DB01991
# Gathered data for DB01992
# Gathered data for DB01993
# Gathered data for DB01994
# Gathered data for DB01995
# Gathered data for DB01996
# Gathered data for DB01997
# Gathered data for DB01998
# Gathered data for DB01999
# Gathered data for DB02000

# %%
# Convert the list to a pandas DataFrame
df = pd.DataFrame(drugs_data)

# Save the DataFrame to a CSV file
df.to_csv('drugbank_data.csv', index=False)

# %%
# Fit the drugs into their respective categories
df["one_category"] = [best_drug_category(x, distinct_drug_categories) for x in df["Drug Categories"]]

# %%
df.one_category.value_counts()
# Out:
# one_category
# Analgesics                  410
# Anti-Inflammatory Agents     82
# Antiviral Agents             75
# Anticonvulsants              70
# Antidepressants              60
# Antifungal Agents            51
# Anticoagulants               46
# Bronchodilators              36
# Diuretics                    33
# Antibiotics                  27
# Antiseptics                  17
# Antihistamines               13
# Mood Stabilizers             12
# Laxatives                     9
# Antipyretics                  2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   DrugBank ID              Name  \
# 0     DB01000       Cyclacillin
# 1     DB01001         Albuterol
# 2     DB01002   Levobupivacaine
# 3     DB01003  Cromoglicic acid
# 4     DB01004       Ganciclovir
#
#                                          Description  \
# 0     A cyclohexylamido analog of penicillanic acid.
# 1  Albuterol is a beta-2 adrenergic receptor agon...
# 2  Levobupivacaine is a drug used for nerve block...
# 3  Cromoglicic acid is a medication used to treat...
# 4  Ganciclovir is a DNA polymerase inhibitor used...
#
#                                  Mechanism of Action  \
# 0  The bactericidal activity of cyclacillin resul...
# 1  In vitro studies and in vivo pharmacologic stu...
# 2  Local anesthetics such as Levobupivacaine bloc...
# 3  Cromoglicate inhibits degranulation of mast ce...
# 4  Ganciclovir's antiviral activity inhibits viru...
#
#                                           Indication  \
# 0  For the treatment of bacterial infections caus...
# 1  Salbutamol is indicated for (i) the symptomati...
# 2  For the production of local or regional anesth...
# 3  For the management of patients with bronchial ...
# 4  For induction and maintenance in the treatment...
#
#                                     Pharmacodynamics  \
# 0  Cyclacillin, a penicillin, is a cyclohexylamid...
# 1  Salbutamol (INN) or albuterol (USAN), a modera...
# 2  Levobupivacaine, a local anesthetic agent, is ...
# 3  Cromoglicate or cromolyn (USAN), a synthetic c...
# 4  Ganciclovir is a synthetic nucleoside analogue...
#
#                                           Absorption  \
# 0                               Moderately absorbed.
# 1  Following inhalation, salbutamol acts topicall...
# 2  The plasma concentration of levobupivacaine fo...
# 3                                                 1%
# 4  Poorly absorbed systemically following oral ad...
#
#                               Volume of Distribution  \
# 0                                      Not Available
# 1  The volume of distribution recorded for intrav...
# 2  66.91 ±18.23 L [after intravenous administrati...
# 3                                      Not Available
# 4                                   0.74 ± 0.15 L/kg
#
#                                      Protein Binding  \
# 0                                      Not Available
# 1  Salbutamol is only weakly bound to plasma prot...
# 2                                               >97%
# 3                                      Not Available
# 4                                            1 to 2%
#
#                                           Metabolism  \
# 0                                      Not Available
# 1  Salbutamol is not metabolized in the lung but ...
# 2  Levobupivacaine is extensively metabolized wit...
# 3                                      Not Available
# 4  Little to no metabolism, about 90% of plasma g...
#
#                                      Drug Categories      one_category
# 0  Amides\nAnti-Bacterial Agents\nAnti-Infective ...       Antibiotics
# 1  Adrenergic Agents\nAdrenergic Agonists\nAdrene...   Bronchodilators
# 2  Amides\nAmines\nAnesthetics\nAnesthetics, Loca...        Analgesics
# 3  Adrenergics, Inhalants\nAgents for Dermatitis,...    Antihistamines
# 4  Agents Causing Muscle Toxicity\nAgents that re...  Antiviral Agents

# %% [markdown]
# ### Variance of Similarity Analysis

# %%
# One-line test
# Fetch data
source = [x for x in list(df.iloc[1])[1:] if x.lower().strip() != "not available"]
vectors = embed_vector(source)

# Convert the list of vectors to a numpy array
vector_array = np.array(vectors)

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(vector_array)

# Print the similarity matrix
# print(similarity_matrix)

# Create a heatmap to visualize the similarity matrix
plt.figure(figsize=(8, 6))
sns.heatmap(similarity_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Cosine Similarity Heatmap')
plt.xlabel('Vector Index')
plt.ylabel('Vector Index')
plt.show()

def analyze_similarity_matrix_without_self(similarity_matrix, plot = False):
    # Remove self-similarity by setting the diagonal to NaN
    np.fill_diagonal(similarity_matrix, np.nan)
    
    # Calculate the variance of the similarity matrix ignoring NaN values
    variance = np.nanvar(similarity_matrix)
    
    # Flatten the similarity matrix to get the distribution of values, excluding NaN values
    distribution = similarity_matrix.flatten()
    distribution = distribution[~np.isnan(distribution)]
    
    if plot:    
        # Plot the distribution as a histogram
        plt.figure(figsize=(8, 6))
        sns.histplot(distribution, bins=20, kde=True)
        plt.title('Distribution of Similarity Values (without self-similarity)')
        plt.xlabel('Similarity Value')
        plt.ylabel('Frequency')
        plt.show()
    else:
        return variance
    return variance

vector_array = np.array(vectors)
similarity_matrix = cosine_similarity(vector_array)

variance = analyze_similarity_matrix_without_self(similarity_matrix, plot=True)
print(f"Variance of the similarity matrix (without self-similarity): {variance}")
# Out:
# Variance of the similarity matrix (without self-similarity): 0.0013763093277161147

# %%
# Iterate and add the variance column to the DF
df["sim_variance"] = [analyze_similarity_matrix_without_self(
    cosine_similarity(
        np.array(
            embed_vector(
                [i for i in list(df.iloc[x]) if i.strip().lower() != "not available"]
                )
            )
        )
    ) for x in range(len(df))]

# %%
plot_variance_distribution(df.sim_variance)
# Out:
# True

# %% [markdown]
# ### PCA

# %%
import pandas as pd

# Load the CSV data into a DataFrame
df = pd.read_csv("./drugbank_data.csv")

# Example of distinct drug categories
distinct_drug_categories = ["Antibiotic", "Analgesic", "Antidepressant", "Antiviral", "Antifungal"]

# Define the function to determine the best drug category
def best_drug_category(drug_categories, distinct_categories):
    # Check if the input is valid
    if not isinstance(drug_categories, str) or not drug_categories:
        return "Unknown"  # Default category if input is invalid or empty
    # Split the drug categories if they are combined in a single string
    drug_category_list = drug_categories.split(',')
    # Example logic to find the best match (you can customize this logic)
    for category in drug_category_list:
        if category.strip() in distinct_categories:
            return category.strip()
    return "Unknown"  # Default category if no match is found

# Replace NaN values in the 'Drug Categories' column with an empty string
df["Drug Categories"].fillna("", inplace=True)

# Apply the function to each row in the DataFrame
df["one_category"] = df["Drug Categories"].apply(lambda x: best_drug_category(x, distinct_drug_categories))

# Display the DataFrame with the new category column
print(df.head())
# Out:
#   DrugBank ID              Name  \
# 0     DB01000       Cyclacillin
# 1     DB01001         Albuterol
# 2     DB01002   Levobupivacaine
# 3     DB01003  Cromoglicic acid
# 4     DB01004       Ganciclovir
#
#                                          Description  \
# 0     A cyclohexylamido analog of penicillanic acid.
# 1  Albuterol is a beta-2 adrenergic receptor agon...
# 2  Levobupivacaine is a drug used for nerve block...
# 3  Cromoglicic acid is a medication used to treat...
# 4  Ganciclovir is a DNA polymerase inhibitor used...
#
#                                  Mechanism of Action  \
# 0  The bactericidal activity of cyclacillin resul...
# 1  In vitro studies and in vivo pharmacologic stu...
# 2  Local anesthetics such as Levobupivacaine bloc...
# 3  Cromoglicate inhibits degranulation of mast ce...
# 4  Ganciclovir's antiviral activity inhibits viru...
#
#                                           Indication  \
# 0  For the treatment of bacterial infections caus...
# 1  Salbutamol is indicated for (i) the symptomati...
# 2  For the production of local or regional anesth...
# 3  For the management of patients with bronchial ...
# 4  For induction and maintenance in the treatment...
#
#                                     Pharmacodynamics  \
# 0  Cyclacillin, a penicillin, is a cyclohexylamid...
# 1  Salbutamol (INN) or albuterol (USAN), a modera...
# 2  Levobupivacaine, a local anesthetic agent, is ...
# 3  Cromoglicate or cromolyn (USAN), a synthetic c...
# 4  Ganciclovir is a synthetic nucleoside analogue...
#
#                                           Absorption  \
# 0                               Moderately absorbed.
# 1  Following inhalation, salbutamol acts topicall...
# 2  The plasma concentration of levobupivacaine fo...
# 3                                                 1%
# 4  Poorly absorbed systemically following oral ad...
#
#                               Volume of Distribution  \
# 0                                      Not Available
# 1  The volume of distribution recorded for intrav...
# 2  66.91 ±18.23 L [after intravenous administrati...
# 3                                      Not Available
# 4                                   0.74 ± 0.15 L/kg
#
#                                      Protein Binding  \
# 0                                      Not Available
# 1  Salbutamol is only weakly bound to plasma prot...
# 2                                               >97%
# 3                                      Not Available
# 4                                            1 to 2%
#
#                                           Metabolism  \
# 0                                      Not Available
# 1  Salbutamol is not metabolized in the lung but ...
# 2  Levobupivacaine is extensively metabolized wit...
# 3                                      Not Available
# 4  Little to no metabolism, about 90% of plasma g...
#
#                                      Drug Categories one_category
# 0  Amides\nAnti-Bacterial Agents\nAnti-Infective ...      Unknown
# 1  Adrenergic Agents\nAdrenergic Agonists\nAdrene...      Unknown
# 2  Amides\nAmines\nAnesthetics\nAnesthetics, Loca...      Unknown
# 3  Adrenergics, Inhalants\nAgents for Dermatitis,...      Unknown
# 4  Agents Causing Muscle Toxicity\nAgents that re...      Unknown
# /var/folders/fq/jhg4d1x54s7djyrxjpq4h4b80000gn/T/ipykernel_12116/1236413944.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Drug Categories"].fillna("", inplace=True)

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

label_column = "Name"

def chunk_list(lst, chunk_size, token_limit):
    """Yield successive chunks from lst with a limit on chunk size and token count."""
    chunk = []
    total_tokens = 0
    for text in lst:
        token_count = len(text.split())
        if len(chunk) >= chunk_size or (total_tokens + token_count) > token_limit:
            yield chunk
            chunk = []
            total_tokens = 0
        chunk.append(text)
        total_tokens += token_count
    if chunk:
        yield chunk

def transform_text_columns_to_embeddings(data, text_columns, chunk_size=128, token_limit=6000):
    # Concatenate all text columns into a single string for each row
    combined_text = data[text_columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

    combined_text.replace("Not Available", "")
    
    embeddings = []
    
    # Process the text data in chunks to avoid batch size and token limits
    for text_chunk in chunk_list(combined_text.tolist(), chunk_size, token_limit):
        chunk_embeddings = embed_vector(text_chunk)
        embeddings.extend(chunk_embeddings)
    
    return embeddings

# Define the text columns (assuming the text columns are all except 'DrugBank ID')
text_columns = df.columns.drop('DrugBank ID')

# Transform the text columns into vector embeddings
embeddings = transform_text_columns_to_embeddings(df, text_columns)

# Extract the labels
labels = df[label_column]
categories = df["one_category"]

def perform_pca(embeddings, n_components=2):
    pca = PCA(n_components=n_components)
    pca_result = pca.fit_transform(embeddings)
    return pca_result

# Perform PCA to reduce the dimensionality to 2 components
pca_result = perform_pca(embeddings)

# %%
pca_data = pd.DataFrame({
        'Principal Component 1': pca_result[:, 0],
        'Principal Component 2': pca_result[:, 1],
        'Label': labels,
        'Category': categories
    })

# %%
# Plot PCA results with Matplotlib and mplcursors
def plot_pca_result_with_labels(pca_result, labels):
    df = pd.DataFrame({
        'Principal Component 1': pca_result[:, 0],
        'Principal Component 2': pca_result[:, 1],
        'Label': labels
    })
    
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(
        df['Principal Component 1'], df['Principal Component 2'],
        c=pd.factorize(df['Label'])[0], cmap='viridis', alpha=0.7
    )
    
    plt.title('PCA of Text Embeddings')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.grid(True)
    plt.show()

plot_pca_result_with_labels(pca_result, labels)

# %% [markdown]
# **SAVE SEPARATELY TO TEXT FILES**

# %%
import pandas as pd
import os

# Directory to save text files
output_dir = './data/drugbank/'
os.makedirs(output_dir, exist_ok=True)

# Function to save each row as a text file
def save_row_as_text(row, output_dir):
    if row["DrugBank ID"] != "N/A":
        file_name = f"{row['DrugBank ID']}.txt"
        file_path = os.path.join(output_dir, file_name)
        with open(file_path, 'w') as file:
            for column, value in row.items():
                file.write(f"{column}: {value}\n")

# Save each row in the dataframe as a text file
df.apply(lambda row: save_row_as_text(row, output_dir), axis=1)

# List the created files to verify
os.listdir(output_dir)
# Out:
# ['DB01937.txt',
#  'DB01089.txt',
#  'DB01923.txt',
#  'DB01738.txt',
#  'DB01710.txt',
#  'DB01076.txt',
#  'DB01062.txt',
#  'DB01704.txt',
#  'DB01248.txt',
#  'DB01274.txt',
#  'DB01512.txt',
#  'DB01506.txt',
#  'DB01260.txt',
#  'DB01499.txt',
#  'DB02153.txt',
#  'DB01328.txt',
#  'DB01466.txt',
#  'DB01472.txt',
#  'DB01843.txt',
#  'DB01857.txt',
#  'DB01880.txt',
#  'DB01658.txt',
#  'DB01664.txt',
#  'DB01102.txt',
#  'DB01116.txt',
#  'DB01670.txt',
#  'DB01117.txt',
#  'DB01671.txt',
#  'DB01665.txt',
#  'DB01103.txt',
#  'DB01895.txt',
#  'DB01659.txt',
#  'DB01881.txt',
#  'DB01856.txt',
#  'DB01842.txt',
#  'DB01473.txt',
#  'DB01301.txt',
#  'DB01467.txt',
#  'DB01329.txt',
#  'DB01498.txt',
#  'DB01261.txt',
#  'DB01275.txt',
#  'DB01513.txt',
#  'DB00157.txt',
#  'DB01249.txt',
#  'DB01063.txt',
#  'DB01705.txt',
#  'DB01711.txt',
#  'DB01077.txt',
#  'DB01739.txt',
#  'DB01922.txt',
#  'DB01936.txt',
#  'DB01088.txt',
#  'DB01920.txt',
#  'DB01934.txt',
#  'DB04864.txt',
#  'DB01908.txt',
#  'DB01049.txt',
#  'DB01707.txt',
#  'DB01061.txt',
#  'DB01075.txt',
#  'DB01713.txt',
#  'DB01288.txt',
#  'DB01539.txt',
#  'DB01263.txt',
#  'DB01505.txt',
#  'DB01511.txt',
#  'DB01277.txt',
#  'DB01459.txt',
#  'DB01471.txt',
#  'DB01465.txt',
#  'DB01303.txt',
#  'DB01854.txt',
#  'DB01698.txt',
#  'DB01840.txt',
#  'DB01868.txt',
#  'DB01897.txt',
#  'DB01129.txt',
#  'DB01883.txt',
#  'DB01673.txt',
#  'DB01115.txt',
#  'DB01101.txt',
#  'DB01667.txt',
#  'DB01100.txt',
#  'DB01666.txt',
#  'DB01672.txt',
#  'DB01114.txt',
#  'DB01882.txt',
#  'DB01896.txt',
#  'DB01128.txt',
#  'DB01841.txt',
#  'DB01699.txt',
#  'DB01855.txt',
#  'DB01464.txt',
#  'DB01470.txt',
#  'DB01458.txt',
#  'DB01510.txt',
#  'DB01276.txt',
#  'DB01262.txt',
#  'DB01538.txt',
#  'DB01289.txt',
#  'DB01074.txt',
#  'DB01712.txt',
#  'DB01706.txt',
#  'DB01060.txt',
#  'DB01048.txt',
#  'DB01909.txt',
#  'DB01935.txt',
#  'DB01921.txt',
#  'DB01919.txt',
#  'DB01925.txt',
#  'DB01931.txt',
#  'DB01064.txt',
#  'DB01702.txt',
#  'DB01716.txt',
#  'DB01070.txt',
#  'DB01058.txt',
#  'DB00811.txt',
#  'DB01299.txt',
#  'DB01500.txt',
#  'DB01266.txt',
#  'DB01272.txt',
#  'DB01514.txt',
#  'DB01528.txt',
#  'DB01474.txt',
#  'DB01306.txt',
#  'DB01460.txt',
#  'DB01448.txt',
#  'DB00030.txt',
#  '.DS_Store',
#  'DB01879.txt',
#  'DB01689.txt',
#  'DB01851.txt',
#  'DB01110.txt',
#  'DB01676.txt',
#  'DB01662.txt',
#  'DB01104.txt',
#  'DB01892.txt',
#  'DB01138.txt',
#  'DB01887.txt',
#  'DB01139.txt',
#  'DB01893.txt',
#  'DB01663.txt',
#  'DB01105.txt',
#  'DB01111.txt',
#  'DB01677.txt',
#  'DB01844.txt',
#  'DB01850.txt',
#  'DB01688.txt',
#  'DB01878.txt',
#  'DB01307.txt',
#  'DB01461.txt',
#  'DB01475.txt',
#  'DB01529.txt',
#  'DB01273.txt',
#  'DB01515.txt',
#  'DB01501.txt',
#  'DB01267.txt',
#  'DB01298.txt',
#  'DB02961.txt',
#  'DB03882.txt',
#  'DB01059.txt',
#  'DB01717.txt',
#  'DB01071.txt',
#  'DB01065.txt',
#  'DB01703.txt',
#  'DB01930.txt',
#  'DB01924.txt',
#  'DB01918.txt',
#  'DB01932.txt',
#  'DB01926.txt',
#  'DB01098.txt',
#  'DB01073.txt',
#  'DB01715.txt',
#  'DB01701.txt',
#  'DB01067.txt',
#  'DB01729.txt',
#  'DB01271.txt',
#  'DB01265.txt',
#  'DB01503.txt',
#  'DB01259.txt',
#  'DB01488.txt',
#  'DB01463.txt',
#  'DB01477.txt',
#  'DB01339.txt',
#  'DB01846.txt',
#  'DB01852.txt',
#  'DB01107.txt',
#  'DB01661.txt',
#  'DB01675.txt',
#  'DB01113.txt',
#  'DB01885.txt',
#  'DB01891.txt',
#  'DB01649.txt',
#  'DB01648.txt',
#  'DB01890.txt',
#  'DB01884.txt',
#  'DB01674.txt',
#  'DB01112.txt',
#  'DB01106.txt',
#  'DB01853.txt',
#  'DB01847.txt',
#  'DB01338.txt',
#  'DB01476.txt',
#  'DB01462.txt',
#  'DB01489.txt',
#  'DB01264.txt',
#  'DB01502.txt',
#  'DB01516.txt',
#  'DB01270.txt',
#  'DB01728.txt',
#  'DB01700.txt',
#  'DB01066.txt',
#  'DB01072.txt',
#  'DB01714.txt',
#  'DB01927.txt',
#  'DB01099.txt',
#  'DB01933.txt',
#  'DB01954.txt',
#  'DB01940.txt',
#  'DB01798.txt',
#  'DB01968.txt',
#  'DB01029.txt',
#  'DB01997.txt',
#  'DB01983.txt',
#  'DB01015.txt',
#  'DB01773.txt',
#  'DB01767.txt',
#  'DB01001.txt',
#  'DB01559.txt',
#  'DB01571.txt',
#  'DB01217.txt',
#  'DB01203.txt',
#  'DB01565.txt',
#  'DB01388.txt',
#  'DB01439.txt',
#  'DB01405.txt',
#  'DB01363.txt',
#  'DB01377.txt',
#  'DB01411.txt',
#  'DB01820.txt',
#  'DB01834.txt',
#  'DB01808.txt',
#  'DB01149.txt',
#  'DB01161.txt',
#  'DB01607.txt',
#  'DB01613.txt',
#  'DB01175.txt',
#  'DB01612.txt',
#  'DB01174.txt',
#  'DB01160.txt',
#  'DB01606.txt',
#  'DB01148.txt',
#  'DB01809.txt',
#  'DB01835.txt',
#  'DB01821.txt',
#  'DB01410.txt',
#  'DB01404.txt',
#  'DB01362.txt',
#  'DB01438.txt',
#  'DB01202.txt',
#  'DB01564.txt',
#  'DB01570.txt',
#  'DB01216.txt',
#  'DB01558.txt',
#  'DB01766.txt',
#  'DB01000.txt',
#  'DB01014.txt',
#  'DB01772.txt',
#  'DB01982.txt',
#  'DB01028.txt',
#  'DB01996.txt',
#  'DB01969.txt',
#  'DB01799.txt',
#  'DB01941.txt',
#  'DB01955.txt',
#  'DB01957.txt',
#  'DB01758.txt',
#  'DB01980.txt',
#  'DB01994.txt',
#  'DB01002.txt',
#  'DB01764.txt',
#  'DB01016.txt',
#  'DB01599.txt',
#  'DB01228.txt',
#  'DB01566.txt',
#  'DB01200.txt',
#  'DB01214.txt',
#  'DB01572.txt',
#  'DB01348.txt',
#  'DB01412.txt',
#  'DB01406.txt',
#  'DB01189.txt',
#  'DB01837.txt',
#  'DB01823.txt',
#  'DB01638.txt',
#  'DB01176.txt',
#  'DB01610.txt',
#  'DB01604.txt',
#  'DB01162.txt',
#  'DB01605.txt',
#  'DB01163.txt',
#  'DB01177.txt',
#  'DB01611.txt',
#  'DB01639.txt',
#  'DB01822.txt',
#  'DB01188.txt',
#  'DB01836.txt',
#  'DB01407.txt',
#  'DB01413.txt',
#  'DB01375.txt',
#  'DB01349.txt',
#  'DB01215.txt',
#  'DB01573.txt',
#  'DB01567.txt',
#  'DB01201.txt',
#  'DB01229.txt',
#  'DB01598.txt',
#  'DB01771.txt',
#  'DB01017.txt',
#  'DB01003.txt',
#  'DB01765.txt',
#  'DB01995.txt',
#  'DB01981.txt',
#  'DB01759.txt',
#  'DB01956.txt',
#  'DB01942.txt',
#  'DB01946.txt',
#  'DB01952.txt',
#  'DB01761.txt',
#  'DB01007.txt',
#  'DB01013.txt',
#  'DB01775.txt',
#  'DB01985.txt',
#  'DB01749.txt',
#  'DB01991.txt',
#  'DB01588.txt',
#  'DB01205.txt',
#  'DB01563.txt',
#  'DB01577.txt',
#  'DB01211.txt',
#  'DB01239.txt',
#  'DB01403.txt',
#  'DB01365.txt',
#  'DB00047.txt',
#  'DB01359.txt',
#  'DB01832.txt',
#  'DB01198.txt',
#  'DB01826.txt',
#  'DB01615.txt',
#  'DB01173.txt',
#  'DB01167.txt',
#  'DB01601.txt',
#  'DB01629.txt',
#  'DB01628.txt',
#  'DB01166.txt',
#  'DB01600.txt',
#  'DB01614.txt',
#  'DB01172.txt',
#  'DB01199.txt',
#  'DB01827.txt',
#  'DB01833.txt',
#  'DB00046.txt',
#  'DB01364.txt',
#  'DB01370.txt',
#  'DB01416.txt',
#  'DB01238.txt',
#  'DB01576.txt',
#  'DB01210.txt',
#  'DB01204.txt',
#  'DB01562.txt',
#  'DB01589.txt',
#  'DB01990.txt',
#  'DB01748.txt',
#  'DB01984.txt',
#  'DB01012.txt',
#  'DB01774.txt',
#  'DB01760.txt',
#  'DB01006.txt',
#  'DB01953.txt',
#  'DB01947.txt',
#  'DB01979.txt',
#  'DB01951.txt',
#  'DB01789.txt',
#  'DB01945.txt',
#  'DB01776.txt',
#  'DB01010.txt',
#  'DB01004.txt',
#  'DB01762.txt',
#  'DB01992.txt',
#  'DB01038.txt',
#  'DB01986.txt',
#  'DB01212.txt',
#  'DB01574.txt',
#  'DB01560.txt',
#  'DB01206.txt',
#  'DB01548.txt',
#  'DB01399.txt',
#  'DB01366.txt',
#  'DB01400.txt',
#  'DB01414.txt',
#  'DB01428.txt',
#  'DB01819.txt',
#  'DB01825.txt',
#  'DB01831.txt',
#  'DB01602.txt',
#  'DB01164.txt',
#  'DB08626.txt',
#  'DB01170.txt',
#  'DB01616.txt',
#  'DB01158.txt',
#  'DB01159.txt',
#  'DB01171.txt',
#  'DB01603.txt',
#  'DB01165.txt',
#  'DB01830.txt',
#  'DB01824.txt',
#  'DB01818.txt',
#  'DB01429.txt',
#  'DB01415.txt',
#  'DB01373.txt',
#  'DB01367.txt',
#  'DB01401.txt',
#  'DB01549.txt',
#  'DB01561.txt',
#  'DB01207.txt',
#  'DB01213.txt',
#  'DB01575.txt',
#  'DB01039.txt',
#  'DB01987.txt',
#  'DB01993.txt',
#  'DB11558.txt',
#  'DB01005.txt',
#  'DB01763.txt',
#  'DB01777.txt',
#  'DB01011.txt',
#  'DB01944.txt',
#  'DB01788.txt',
#  'DB01950.txt',
#  'DB01978.txt',
#  'DB01975.txt',
#  'DB01961.txt',
#  'DB01949.txt',
#  'DB01791.txt',
#  'DB01785.txt',
#  'DB01008.txt',
#  'DB01034.txt',
#  'DB01752.txt',
#  'DB01746.txt',
#  'DB01020.txt',
#  'DB01593.txt',
#  'DB02930.txt',
#  'DB01587.txt',
#  'DB01578.txt',
#  'DB01550.txt',
#  'DB01236.txt',
#  'DB01222.txt',
#  'DB01544.txt',
#  'DB01381.txt',
#  'DB01395.txt',
#  'DB01418.txt',
#  'DB01424.txt',
#  'DB01342.txt',
#  'DB01356.txt',
#  'DB01430.txt',
#  'DB01815.txt',
#  'DB01183.txt',
#  'DB01829.txt',
#  'DB01197.txt',
#  'DB01168.txt',
#  'DB01140.txt',
#  'DB01626.txt',
#  'DB01632.txt',
#  'DB01154.txt',
#  'DB01633.txt',
#  'DB01155.txt',
#  'DB01141.txt',
#  'DB01627.txt',
#  'DB01169.txt',
#  'DB01828.txt',
#  'DB01196.txt',
#  'DB01182.txt',
#  'DB01814.txt',
#  'DB01800.txt',
#  'DB01357.txt',
#  'DB01431.txt',
#  'DB01425.txt',
#  'DB01419.txt',
#  'DB01394.txt',
#  'DB01380.txt',
#  'DB01223.txt',
#  'DB01545.txt',
#  'DB01551.txt',
#  'nan.txt',
#  'DB01237.txt',
#  'DB01579.txt',
#  'DB01586.txt',
#  'DB01592.txt',
#  'DB01747.txt',
#  'DB01021.txt',
#  'DB01035.txt',
#  'DB01753.txt',
#  'DB01009.txt',
#  'DB01784.txt',
#  'DB01790.txt',
#  'DB01948.txt',
#  'DB01960.txt',
#  'DB01974.txt',
#  'DB01962.txt',
#  'DB01976.txt',
#  'DB01786.txt',
#  'DB01792.txt',
#  'DB01779.txt',
#  'DB01023.txt',
#  'DB01745.txt',
#  'DB01751.txt',
#  'DB01989.txt',
#  'DB01037.txt',
#  'DB01584.txt',
#  'DB01590.txt',
#  'DB01209.txt',
#  'DB01547.txt',
#  'DB01221.txt',
#  'DB01235.txt',
#  'DB01553.txt',
#  'DB00936.txt',
#  'DB01396.txt',
#  'DB01382.txt',
#  'DB01369.txt',
#  'DB01433.txt',
#  'DB01355.txt',
#  'DB01341.txt',
#  'DB01427.txt',
#  'DB01816.txt',
#  'DB01802.txt',
#  'DB01194.txt',
#  'DB01180.txt',
#  'DB01619.txt',
#  'DB01157.txt',
#  'DB01631.txt',
#  'DB01625.txt',
#  'DB01143.txt',
#  'DB01624.txt',
#  'DB01142.txt',
#  'DB01156.txt',
#  'DB01630.txt',
#  'DB01618.txt',
#  'DB01181.txt',
#  'DB01195.txt',
#  'DB01803.txt',
#  'DB01817.txt',
#  'DB01340.txt',
#  'DB01426.txt',
#  'DB01432.txt',
#  'DB01354.txt',
#  'DB01397.txt',
#  'DB01234.txt',
#  'DB01552.txt',
#  'DB01546.txt',
#  'DB01220.txt',
#  'DB01208.txt',
#  'DB01591.txt',
#  'DB01988.txt',
#  'DB01750.txt',
#  'DB01036.txt',
#  'DB01022.txt',
#  'DB01744.txt',
#  'DB01778.txt',
#  'DB01793.txt',
#  'DB01977.txt',
#  'DB01963.txt',
#  'DB01783.txt',
#  'DB01797.txt',
#  'DB01967.txt',
#  'DB01973.txt',
#  'DB01740.txt',
#  'DB01998.txt',
#  'DB01026.txt',
#  'DB01032.txt',
#  'DB01754.txt',
#  'DB01768.txt',
#  'DB01581.txt',
#  'DB01595.txt',
#  'DB01224.txt',
#  'DB01542.txt',
#  'DB01556.txt',
#  'DB01230.txt',
#  'DB01218.txt',
#  'DB01393.txt',
#  'DB01436.txt',
#  'DB01422.txt',
#  'DB01344.txt',
#  'DB01378.txt',
#  'DB01191.txt',
#  'DB01185.txt',
#  'DB01813.txt',
#  'DB01807.txt',
#  'DB01634.txt',
#  'DB01152.txt',
#  'DB01146.txt',
#  'DB01620.txt',
#  'DB01608.txt',
#  'DB01609.txt',
#  'DB01147.txt',
#  'DB01621.txt',
#  'DB01635.txt',
#  'DB01153.txt',
#  'DB01806.txt',
#  'DB01812.txt',
#  'DB01184.txt',
#  'DB01190.txt',
#  'DB01423.txt',
#  'DB01345.txt',
#  'DB01351.txt',
#  'DB01437.txt',
#  'DB11195.txt',
#  'DB01392.txt',
#  'DB01219.txt',
#  'DB01557.txt',
#  'DB01231.txt',
#  'DB01225.txt',
#  'DB01543.txt',
#  'DB01594.txt',
#  'DB01580.txt',
#  'DB01033.txt',
#  'DB01755.txt',
#  'DB01999.txt',
#  'DB01741.txt',
#  'DB01972.txt',
#  'DB01966.txt',
#  'DB01796.txt',
#  'DB01782.txt',
#  'DB01794.txt',
#  'DB01958.txt',
#  'DB01780.txt',
#  'DB01970.txt',
#  'DB01964.txt',
#  'DB01031.txt',
#  'DB01025.txt',
#  'DB01019.txt',
#  'DB01582.txt',
#  'DB01233.txt',
#  'DB01555.txt',
#  'DB01541.txt',
#  'DB01227.txt',
#  'DB01569.txt',
#  'DB13179.txt',
#  'DB01384.txt',
#  'DB01390.txt',
#  'DB01347.txt',
#  'DB01421.txt',
#  'DB01435.txt',
#  'DB01353.txt',
#  'DB01409.txt',
#  'DB01838.txt',
#  'DB01186.txt',
#  'DB01192.txt',
#  'DB01804.txt',
#  'DB06819.txt',
#  'DB01810.txt',
#  'DB01623.txt',
#  'DB01145.txt',
#  'DB01151.txt',
#  'DB01637.txt',
#  'DB01179.txt',
#  'DB01178.txt',
#  'DB01150.txt',
#  'DB01622.txt',
#  'DB01144.txt',
#  'DB01811.txt',
#  'DB01805.txt',
#  'DB01193.txt',
#  'DB01839.txt',
#  'DB01187.txt',
#  'DB00299.txt',
#  'DB01408.txt',
#  'DB01434.txt',
#  'DB01352.txt',
#  'DB01346.txt',
#  'DB01420.txt',
#  'DB01568.txt',
#  'DB01540.txt',
#  'DB01226.txt',
#  'DB01232.txt',
#  'DB01554.txt',
#  'DB01583.txt',
#  'DB01597.txt',
#  'DB01018.txt',
#  'DB01024.txt',
#  'DB01742.txt',
#  'DB01756.txt',
#  'DB01030.txt',
#  'DB01965.txt',
#  'DB01971.txt',
#  'DB01959.txt',
#  'DB01795.txt',
#  'DB01902.txt',
#  'DB01094.txt',
#  'DB01080.txt',
#  'DB01719.txt',
#  'DB01731.txt',
#  'DB01057.txt',
#  'DB01043.txt',
#  'DB01725.txt',
#  'DB01296.txt',
#  'DB01282.txt',
#  'DB01269.txt',
#  'DB01255.txt',
#  'DB01533.txt',
#  'DB01527.txt',
#  'DB01241.txt',
#  'DB01484.txt',
#  'DB01490.txt',
#  'DB01309.txt',
#  'DB01321.txt',
#  'DB01447.txt',
#  'DB01453.txt',
#  'DB01862.txt',
#  'DB01876.txt',
#  'DB01686.txt',
#  'DB01692.txt',
#  'DB01679.txt',
#  'DB01645.txt',
#  'DB01123.txt',
#  'DB01137.txt',
#  'DB01889.txt',
#  'DB01651.txt',
#  'DB01136.txt',
#  'DB03721.txt',
#  'DB01650.txt',
#  'DB01888.txt',
#  'DB01644.txt',
#  'DB01122.txt',
#  'DB01678.txt',
#  'DB01687.txt',
#  'DB01877.txt',
#  'DB01863.txt',
#  'DB01452.txt',
#  'DB01320.txt',
#  'DB01446.txt',
#  'DB09026.txt',
#  'DB01491.txt',
#  'DB01485.txt',
#  'DB01526.txt',
#  'DB01240.txt',
#  'DB01254.txt',
#  'DB01532.txt',
#  'DB01268.txt',
#  'DB01283.txt',
#  'DB01297.txt',
#  'DB01042.txt',
#  'DB01724.txt',
#  'DB01056.txt',
#  'DB01718.txt',
#  'DB01081.txt',
#  'DB01095.txt',
#  'DB01903.txt',
#  'DB01917.txt',
#  'DB01901.txt',
#  'DB01915.txt',
#  'DB01083.txt',
#  'DB01097.txt',
#  'DB01929.txt',
#  'DB01068.txt',
#  'DB01726.txt',
#  'DB01054.txt',
#  'DB01732.txt',
#  'DB01281.txt',
#  'DB01295.txt',
#  'DB01518.txt',
#  'DB01242.txt',
#  'DB01524.txt',
#  'DB01530.txt',
#  'DB01256.txt',
#  'DB01493.txt',
#  'DB01487.txt',
#  'DB01478.txt',
#  'DB01336.txt',
#  'DB01450.txt',
#  'DB01444.txt',
#  'DB01322.txt',
#  'DB01875.txt',
#  'DB01861.txt',
#  'DB01691.txt',
#  'DB01849.txt',
#  'DB01685.txt',
#  'DB01108.txt',
#  'DB01652.txt',
#  'DB01134.txt',
#  'DB01120.txt',
#  'DB01646.txt',
#  'DB01121.txt',
#  'DB01647.txt',
#  'DB01135.txt',
#  'DB01109.txt',
#  'DB01684.txt',
#  'DB01690.txt',
#  'DB08844.txt',
#  'DB01860.txt',
#  'DB01874.txt',
#  'DB01445.txt',
#  'DB01323.txt',
#  'DB01337.txt',
#  'DB01451.txt',
#  'DB01479.txt',
#  'DB01486.txt',
#  'DB01531.txt',
#  'DB01257.txt',
#  'DB01243.txt',
#  'DB01525.txt',
#  'DB01294.txt',
#  'DB01280.txt',
#  'DB01055.txt',
#  'DB01733.txt',
#  'DB01727.txt',
#  'DB01041.txt',
#  'DB01069.txt',
#  'DB01096.txt',
#  'DB01082.txt',
#  'DB01914.txt',
#  'DB01086.txt',
#  'DB01938.txt',
#  'DB01092.txt',
#  'DB01910.txt',
#  'DB01045.txt',
#  'DB01723.txt',
#  'DB01737.txt',
#  'DB01051.txt',
#  'DB01079.txt',
#  'DB01284.txt',
#  'DB01521.txt',
#  'DB01247.txt',
#  'DB01253.txt',
#  'DB01535.txt',
#  'DB01509.txt',
#  'DB01496.txt',
#  'DB01482.txt',
#  'DB01455.txt',
#  'DB01333.txt',
#  'DB01327.txt',
#  'DB01441.txt',
#  'DB01469.txt',
#  'DB01694.txt',
#  'DB01858.txt',
#  'DB01870.txt',
#  'DB01864.txt',
#  'DB01131.txt',
#  'DB01657.txt',
#  'DB01643.txt',
#  'DB01125.txt',
#  'DB01119.txt',
#  'DB01118.txt',
#  'DB01642.txt',
#  'DB01124.txt',
#  'DB01130.txt',
#  'DB01656.txt',
#  'DB01865.txt',
#  'DB01871.txt',
#  'DB01859.txt',
#  'DB01681.txt',
#  'DB01695.txt',
#  'DB01468.txt',
#  'DB01326.txt',
#  'DB01440.txt',
#  'DB01454.txt',
#  'DB01332.txt',
#  'DB01483.txt',
#  'DB01497.txt',
#  'DB01252.txt',
#  'DB01534.txt',
#  'DB01520.txt',
#  'DB01246.txt',
#  'DB01291.txt',
#  'DB01285.txt',
#  'DB01078.txt',
#  'DB01736.txt',
#  'DB01050.txt',
#  'DB01044.txt',
#  'DB01911.txt',
#  'DB01905.txt',
#  'DB01093.txt',
#  'DB01087.txt',
#  'DB01939.txt',
#  'DB01091.txt',
#  'DB01085.txt',
#  'DB01734.txt',
#  'DB01720.txt',
#  'DB01046.txt',
#  'DB01708.txt',
#  'DB01536.txt',
#  'DB01250.txt',
#  'DB01244.txt',
#  'DB01522.txt',
#  'DB01278.txt',
#  'DB01481.txt',
#  'DB01495.txt',
#  'DB01442.txt',
#  'DB01324.txt',
#  'DB01330.txt',
#  'DB01456.txt',
#  'DB01683.txt',
#  'DB01697.txt',
#  'DB01873.txt',
#  'DB01126.txt',
#  'DB01898.txt',
#  'DB01640.txt',
#  'DB01132.txt',
#  'DB01668.txt',
#  'DB01669.txt',
#  'DB01655.txt',
#  'DB01133.txt',
#  'DB01127.txt',
#  'DB01641.txt',
#  'DB01899.txt',
#  'DB01872.txt',
#  'DB01866.txt',
#  'DB01682.txt',
#  'DB01319.txt',
#  'DB01331.txt',
#  'DB01443.txt',
#  'DB01325.txt',
#  'DB01494.txt',
#  'DB01480.txt',
#  'DB01279.txt',
#  'DB01245.txt',
#  'DB01523.txt',
#  'DB01537.txt',
#  'DB01251.txt',
#  'DB01709.txt',
#  'DB01721.txt',
#  'DB01047.txt',
#  'DB01053.txt',
#  'DB01735.txt',
#  'DB01906.txt',
#  'DB01912.txt',
#  'DB01084.txt',
#  'DB01090.txt']
